# %% [markdown]
# <a href="https://colab.research.google.com/github/dhamvi01/Imgae-Face-Recognition-with-Python/blob/main/Face_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Import Libraries

# %%
import cv2
import sys

# %%
faceCascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml') #use file from repo

# %% [markdown]
# #### Input Image

# %%
image = cv2.imread('SC Image.jpeg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# #### Model Building

# %%
# Detect faces in the image
faces = faceCascade.detectMultiScale(
    gray,
    scaleFactor=1.1,
    minNeighbors=5,
    minSize=(30, 30),
    flags = cv2.CASCADE_SCALE_IMAGE
)

# %%
print("Found {0} faces!".format(len(faces)))

# Draw a rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
# Out:
# Found 6 faces!

# %% [markdown]
# #### Result Image

# %%
#img = cv2.imread('logo.png', cv2.IMREAD_UNCHANGED)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=900x600 at 0x7F84D7F642B0>
